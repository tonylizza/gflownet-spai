# %%
import os
import numpy as np
from scipy.io import mmread, mmwrite
from scipy.sparse import isspmatrix, csr_matrix

def process_matrices(data_directory):
    # Create subdirectories if they do not exist
    matrices_dir = os.path.join(data_directory, 'matrices')
    b_vectors_dir = os.path.join(data_directory, 'b_vectors')
    os.makedirs(matrices_dir, exist_ok=True)
    os.makedirs(b_vectors_dir, exist_ok=True)

    # Process all .mtx files in the main directory
    for file_name in os.listdir(data_directory):
        if file_name.endswith(".mtx"):
            # Paths to the matrix file and b vector file
            matrix_file = os.path.join(data_directory, file_name)
            filename_root = os.path.splitext(file_name)[0]
            b_vector_file = os.path.join(b_vectors_dir, f"{filename_root}_b.mtx")

            print(f"Processing matrix: {matrix_file}")

            # Load the matrix
            matrix = mmread(matrix_file)

            # Ensure the matrix is in sparse format
            if not isspmatrix(matrix):
                matrix = csr_matrix(matrix)

            # Check if the _b.mtx file already exists
            if not os.path.exists(b_vector_file):
                print(f"{b_vector_file} not found. Generating solution vector...")

                # Generate a random x vector with the correct dimensions
                try:
                    x_vector = np.random.rand(matrix.shape[1])
                    print(f"x vector generated with shape: {x_vector.shape}")

                    # Multiply matrix by x to get the solution vector b
                    b_vector = matrix.dot(x_vector)
                    print(f"b vector generated with shape: {b_vector.shape}")

                    # Save the result in Market Matrix format in the b_vectors subdirectory
                    mmwrite(b_vector_file, csr_matrix(b_vector.reshape(-1, 1)))
                    print(f"Saved b vector: {b_vector_file}")
                except Exception as e:
                    print(f"Error generating or saving b vector for {file_name}: {e}")
            else:
                print(f"{b_vector_file} already exists, skipping.")

            # Move the original matrix to the matrices subdirectory
            new_matrix_path = os.path.join(matrices_dir, file_name)
            os.rename(matrix_file, new_matrix_path)
            print(f"Moved matrix file to {new_matrix_path}")

if __name__ == "__main__":
    # Set the directory containing the data (replace with your directory path)
    data_directory = "/Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices"
    
    process_matrices(data_directory)
# Out:
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-9.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-9_b.mtx not found. Generating solution vector...
# x vector generated with shape: (289,)
# b vector generated with shape: (289,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-9_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-9.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-8.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-8_b.mtx not found. Generating solution vector...
# x vector generated with shape: (145,)
# b vector generated with shape: (145,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-8_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-8.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-15.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-15_b.mtx not found. Generating solution vector...
# x vector generated with shape: (16641,)
# b vector generated with shape: (16641,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-15_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-15.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-14.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-14_b.mtx not found. Generating solution vector...
# x vector generated with shape: (8321,)
# b vector generated with shape: (8321,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-14_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-14.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-16.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-16_b.mtx not found. Generating solution vector...
# x vector generated with shape: (65137,)
# b vector generated with shape: (65137,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-16_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-16.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-17.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-17_b.mtx not found. Generating solution vector...
# x vector generated with shape: (95538,)
# b vector generated with shape: (95538,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-17_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-17.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-13.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-13_b.mtx not found. Generating solution vector...
# x vector generated with shape: (4225,)
# b vector generated with shape: (4225,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-13_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-13.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-12.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-12_b.mtx not found. Generating solution vector...
# x vector generated with shape: (2113,)
# b vector generated with shape: (2113,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-12_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-12.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-10.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-10_b.mtx not found. Generating solution vector...
# x vector generated with shape: (545,)
# b vector generated with shape: (545,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-10_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-10.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-11.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-11_b.mtx not found. Generating solution vector...
# x vector generated with shape: (1089,)
# b vector generated with shape: (1089,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-11_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-11.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-20.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-20_b.mtx not found. Generating solution vector...
# x vector generated with shape: (769494,)
# b vector generated with shape: (769494,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-20_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-20.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-19.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-19_b.mtx not found. Generating solution vector...
# x vector generated with shape: (436218,)
# b vector generated with shape: (436218,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-19_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-19.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-18.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-18_b.mtx not found. Generating solution vector...
# x vector generated with shape: (197830,)
# b vector generated with shape: (197830,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-18_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-18.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-5.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-5_b.mtx not found. Generating solution vector...
# x vector generated with shape: (25,)
# b vector generated with shape: (25,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-5_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-5.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-4.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-4_b.mtx not found. Generating solution vector...
# x vector generated with shape: (13,)
# b vector generated with shape: (13,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-4_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-4.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-6.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-6_b.mtx not found. Generating solution vector...
# x vector generated with shape: (41,)
# b vector generated with shape: (41,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-6_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-6.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-7.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-7_b.mtx not found. Generating solution vector...
# x vector generated with shape: (81,)
# b vector generated with shape: (81,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-7_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-7.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-3.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-3_b.mtx not found. Generating solution vector...
# x vector generated with shape: (9,)
# b vector generated with shape: (9,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-3_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-3.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-2.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-2_b.mtx not found. Generating solution vector...
# x vector generated with shape: (5,)
# b vector generated with shape: (5,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-2_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-2.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-0.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-0_b.mtx not found. Generating solution vector...
# x vector generated with shape: (4,)
# b vector generated with shape: (4,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-0_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-0.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-1.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-1_b.mtx not found. Generating solution vector...
# x vector generated with shape: (4,)
# b vector generated with shape: (4,)
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/b_vectors/DH-Matrix-1_b.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/matrices/DH-Matrix-1.mtx

# %%
import os
import shutil

def move_b_vectors(data_directory):
    # Create the b_vectors subdirectory if it doesn't exist
    b_vectors_dir = os.path.join(data_directory, 'b_vectors')
    os.makedirs(b_vectors_dir, exist_ok=True)

    # Traverse all nested directories
    for root, dirs, files in os.walk(data_directory):
        for dir_name in dirs:
            matrix_dir = os.path.join(root, dir_name)
            filename_root = dir_name

            # Path to the existing _b.mtx file
            b_vector_file = os.path.join(matrix_dir, f"{filename_root}_b.mtx")

            if os.path.exists(b_vector_file):
                print(f"Found b vector: {b_vector_file}")

                # Destination path for the b vector
                destination_file = os.path.join(b_vectors_dir, f"{filename_root}_b.mtx")

                # Move the b vector to the b_vectors subdirectory
                shutil.move(b_vector_file, destination_file)
                print(f"Moved b vector to {destination_file}")
            else:
                print(f"No b vector found for {filename_root}, skipping.")

if __name__ == "__main__":
    # Set the directory containing the data (replace with your directory path)
    data_directory = "/Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices"
    
    move_b_vectors(data_directory)
# Out:
# No b vector found for tols340, skipping.
# No b vector found for dermatology_5NN, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_33/oscil_dcop_33_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_33_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_34/oscil_dcop_34_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_34_b.mtx
# No b vector found for b_vectors, skipping.
# No b vector found for mhda416, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_02/oscil_dcop_02_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_02_b.mtx
# No b vector found for plskz362, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_05/oscil_dcop_05_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_05_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_51/oscil_dcop_51_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_51_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/cavity01/cavity01_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/cavity01_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_56/oscil_dcop_56_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_56_b.mtx
# No b vector found for bfwb398, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_04/oscil_dcop_04_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_04_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_03/oscil_dcop_03_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_03_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_35/oscil_dcop_35_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_35_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_32/oscil_dcop_32_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_32_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_57/oscil_dcop_57_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_57_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_50/oscil_dcop_50_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_50_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_43/oscil_dcop_43_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_43_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_44/oscil_dcop_44_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_44_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_10/oscil_dcop_10_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_10_b.mtx
# No b vector found for cz308, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_17/oscil_dcop_17_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_17_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_28/oscil_dcop_28_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_28_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_21/oscil_dcop_21_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_21_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_26/oscil_dcop_26_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_26_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_19/oscil_dcop_19_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_19_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_45/oscil_dcop_45_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_45_b.mtx
# No b vector found for celegansneural, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_42/oscil_dcop_42_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_42_b.mtx
# No b vector found for Chebyshev1, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_27/oscil_dcop_27_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_27_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_18/oscil_dcop_18_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_18_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_20/oscil_dcop_20_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_20_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_16/oscil_dcop_16_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_16_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/spaceStation_2/spaceStation_2_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/spaceStation_2_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_29/oscil_dcop_29_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_29_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_11/oscil_dcop_11_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_11_b.mtx
# No b vector found for CAG_mat364, skipping.
# No b vector found for problem1, skipping.
# No b vector found for Ecoli_10NN, skipping.
# No b vector found for str_600, skipping.
# No b vector found for west0381, skipping.
# No b vector found for str_200, skipping.
# No b vector found for impcol_d, skipping.
# No b vector found for Olivetti_norm_10NN, skipping.
# No b vector found for odepa400, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_55/oscil_dcop_55_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_55_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_52/oscil_dcop_52_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_52_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/cavity02/cavity02_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/cavity02_b.mtx
# No b vector found for rajat05, skipping.
# No b vector found for ck400, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_08/oscil_dcop_08_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_08_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_37/oscil_dcop_37_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_37_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_trans_01/oscil_trans_01_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_trans_01_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/hangGlider_1/hangGlider_1_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/hangGlider_1_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/tumorAntiAngiogenesis_3/tumorAntiAngiogenesis_3_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/tumorAntiAngiogenesis_3_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_30/oscil_dcop_30_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_30_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_39/oscil_dcop_39_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_39_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_06/oscil_dcop_06_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_06_b.mtx
# No b vector found for gre_343, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_01/oscil_dcop_01_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_01_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_53/oscil_dcop_53_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_53_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/cavity03/cavity03_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/cavity03_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_54/oscil_dcop_54_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_54_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/cavity04/cavity04_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/cavity04_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_38/oscil_dcop_38_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_38_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_07/oscil_dcop_07_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_07_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/tumorAntiAngiogenesis_2/tumorAntiAngiogenesis_2_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/tumorAntiAngiogenesis_2_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_31/oscil_dcop_31_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_31_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_09/oscil_dcop_09_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_09_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_36/oscil_dcop_36_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_36_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_14/oscil_dcop_14_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_14_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_13/oscil_dcop_13_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_13_b.mtx
# No b vector found for nnc261, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_25/oscil_dcop_25_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_25_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_22/oscil_dcop_22_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_22_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_49/oscil_dcop_49_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_49_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_47/oscil_dcop_47_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_47_b.mtx
# No b vector found for bfwa398, skipping.
# No b vector found for cage7, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_40/oscil_dcop_40_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_40_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_23/oscil_dcop_23_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_23_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/orbitRaising_1/orbitRaising_1_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/orbitRaising_1_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_24/oscil_dcop_24_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_24_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_12/oscil_dcop_12_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_12_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_15/oscil_dcop_15_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_15_b.mtx
# No b vector found for ex2, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_41/oscil_dcop_41_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_41_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_46/oscil_dcop_46_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_46_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/oscil_dcop_48/oscil_dcop_48_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/oscil_dcop_48_b.mtx
# No b vector found for str_400, skipping.
# No b vector found for hor_131, skipping.
# No b vector found for USAir97, skipping.
# No b vector found for matrices, skipping.
# No b vector found for str_0, skipping.
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/poisson2D/poisson2D_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/poisson2D_b.mtx
# Found b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/utm300/utm300_b.mtx
# Moved b vector to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/additional_matrices/b_vectors/utm300_b.mtx

# %%
import os
import numpy as np
from scipy.io import mmread, mmwrite
from scipy.sparse import isspmatrix
from scipy.sparse.linalg import spilu
from scipy.sparse import csr_matrix

def create_ilu_preconditioner(matrix_dir, output_dir):
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Loop through all .mtx files in the matrix directory
    for file_name in os.listdir(matrix_dir):
        if file_name.endswith(".mtx") and not file_name.endswith("_ilu.mtx"):
            matrix_path = os.path.join(matrix_dir, file_name)
            print(f"Processing matrix: {matrix_path}")

            # Load the matrix from the .mtx file
            matrix = mmread(matrix_path)

            # Ensure the matrix is in sparse format
            if not isspmatrix(matrix):
                matrix = csr_matrix(matrix)

            try:
                # Create ILU preconditioner (ILU decomposition)
                ilu = spilu(matrix)

                # Convert the ILU preconditioner to a sparse matrix
                ilu_matrix = ilu.L + ilu.U - csr_matrix(np.eye(matrix.shape[0]))

                # Define the output filename and path
                output_filename = file_name.replace(".mtx", "_ilu.mtx")
                output_path = os.path.join(output_dir, output_filename)

                # Save the ILU preconditioner as a .mtx file
                mmwrite(output_path, ilu_matrix)
                print(f"Saved ILU preconditioner to: {output_path}")

            except Exception as e:
                print(f"Failed to create ILU for {file_name}: {e}")

if __name__ == "__main__":
    # Set the directory containing the matrix files
    matrix_directory = "/Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices"  # Replace with your directory
    output_directory = "/Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices"  # Directory to save ILU matrices

    # Process matrices and create ILU preconditioners
    create_ilu_preconditioner(matrix_directory, output_directory)
# Out:
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-9.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-9_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-8.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-8_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-15.mtx
# /var/folders/df/jtzlym5n0d9b8ttc8phbv7300000gn/T/ipykernel_33156/2745915368.py:27: SparseEfficiencyWarning: spilu converted its input to CSC format
#   ilu = spilu(matrix)
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-15_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-14.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-14_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-16.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-16_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-17.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-17_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-13.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-13_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-12.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-12_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-10.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-10_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-11.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-11_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-5.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-5_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-4.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-4_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-6.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-6_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-7.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-7_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-3.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-3_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-2.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-2_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-0.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-0_ilu.mtx
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/matrices/DH-Matrix-1.mtx
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/DHMats/ilu_matrices/DH-Matrix-1_ilu.mtx

# %%
import os

def get_root_name(filename, suffix):
    """
    Extract the root name from a filename by removing the suffix (e.g., '_ilu.mtx', '_b.mtx').
    """
    return filename.replace(suffix, '')

def get_files_with_suffix(directory, suffix):
    """
    Get a set of root names from filenames in a directory, removing the specified suffix.
    """
    return {get_root_name(f, suffix) for f in os.listdir(directory) if f.endswith(suffix)}

def remove_files_by_root_names(directory, root_names, suffix):
    """
    Remove files in the given directory that have a root name not in the specified root_names set.
    """
    for f in os.listdir(directory):
        if f.endswith(suffix):
            root_name = get_root_name(f, suffix)
            if root_name not in root_names:
                file_path = os.path.join(directory, f)
                print(f"Removing file: {file_path}")
                os.remove(file_path)

def clean_directories(matrices_dir, ilu_matrices_dir, b_vectors_dir):
    # Get the set of root names in the ilu_matrices directory (those that have ILU preconditioners)
    ilu_root_names = get_files_with_suffix(ilu_matrices_dir, '_ilu.mtx')

    # Remove files from the matrices directory that don't have corresponding ILU files
    remove_files_by_root_names(matrices_dir, ilu_root_names, '.mtx')

    # Remove files from the b_vectors directory that don't have corresponding ILU files
    remove_files_by_root_names(b_vectors_dir, ilu_root_names, '_b.mtx')

if __name__ == "__main__":
    # Specify the directories
    matrices_dir = "/Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices"
    ilu_matrices_dir = "/Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/ilu_matrices"
    b_vectors_dir = "/Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors"

    # Clean up the directories by removing unmatched files
    clean_directories(matrices_dir, ilu_matrices_dir, b_vectors_dir)
# Out:
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/kmnist_norm_10NN.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/lowThrust_4.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/wiki-RfA.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/ted_A_unscaled.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/Reuters911.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/cz10228.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/sinc15.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/mnist_test_norm_10NN.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/lhr14c.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/foldoc.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/jan99jac040.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/indianpines_10NN.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/stokes64s.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/g7jac040sc.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/mark3jac020sc.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/mark3jac020.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/har_10NN.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/ncvxqp1.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/g7jac040.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/lhr14.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/cyl6.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/lhr10.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/bayer02.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/lhr11.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/kineticBatchReactor_8.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/sit100.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/kineticBatchReactor_9.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/Fashion_MNIST_norm_10NN.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/stokes64.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/c-45.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/airfoil_2d.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/lhr10c.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/CurlCurl_0.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/g7jac050sc.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/FA.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/coater2.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/usps_norm_5NN.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/lhr11c.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/c-43.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/matrices/c-40.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/g7jac040sc_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/g7jac050sc_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/lhr14_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/indianpines_10NN_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/kineticBatchReactor_8_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/coater2_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/cyl6_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/lhr10_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/CurlCurl_0_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/airfoil_2d_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/cz10228_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/kineticBatchReactor_9_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/lhr11c_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/lhr11_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/kmnist_norm_10NN_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/mnist_test_norm_10NN_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/mark3jac020_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/lowThrust_4_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/Fashion_MNIST_norm_10NN_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/c-40_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/g7jac040_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/foldoc_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/har_10NN_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/bayer02_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/wiki-RfA_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/stokes64s_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/lhr14c_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/jan99jac040_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/Reuters911_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/FA_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/ncvxqp1_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/sit100_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/sinc15_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/c-43_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/ted_A_unscaled_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/lhr10c_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/stokes64_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/mark3jac020sc_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/c-45_b.mtx
# Removing file: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/large_ILU/b_vectors/usps_norm_5NN_b.mtx

# %%
import os
import numpy as np
from scipy.io import mmread, mmwrite
from scipy.sparse import isspmatrix
from scipy.sparse.linalg import spilu
from scipy.sparse import csr_matrix
import shutil

def process_matrices_and_create_ilu(data_directory):
    # Create subdirectories if they do not exist
    matrices_dir = os.path.join(data_directory, 'matrices')
    b_vectors_dir = os.path.join(data_directory, 'b_vectors')
    ilu_matrices_dir = os.path.join(data_directory, 'ilu_matrices')
    
    os.makedirs(matrices_dir, exist_ok=True)
    os.makedirs(b_vectors_dir, exist_ok=True)
    os.makedirs(ilu_matrices_dir, exist_ok=True)

    # Traverse all nested directories
    for root, dirs, files in os.walk(data_directory):
        for dir_name in dirs:
            matrix_dir = os.path.join(root, dir_name)
            filename_root = dir_name

            # Paths to the matrix file and b vector file
            matrix_file = os.path.join(matrix_dir, f"{filename_root}.mtx")
            b_vector_file = os.path.join(b_vectors_dir, f"{filename_root}_b.mtx")
            ilu_output_file = os.path.join(ilu_matrices_dir, f"{filename_root}_ilu.mtx")

            if os.path.exists(matrix_file):
                print(f"Processing matrix: {matrix_file}")

                # Load the matrix
                matrix = mmread(matrix_file)

                # Ensure the matrix is in sparse format
                if not isspmatrix(matrix):
                    matrix = csr_matrix(matrix)

                try:
                    # Create ILU preconditioner (ILU decomposition)
                    print(f"Attempting to create ILU preconditioner for {matrix_file}...")
                    ilu = spilu(matrix)

                    # Convert the ILU preconditioner to a sparse matrix
                    ilu_matrix = ilu.L + ilu.U - csr_matrix(np.eye(matrix.shape[0]))

                    # Save the ILU preconditioner as a .mtx file
                    mmwrite(ilu_output_file, ilu_matrix)
                    print(f"Saved ILU preconditioner to: {ilu_output_file}")

                    # Move the original matrix file to the matrices subdirectory
                    new_matrix_path = os.path.join(matrices_dir, f"{filename_root}.mtx")
                    shutil.move(matrix_file, new_matrix_path)
                    print(f"Moved matrix file to {new_matrix_path}")

                    # Check if the _b.mtx file already exists
                    if os.path.exists(b_vector_file):
                        print(f"{b_vector_file} already exists, moving to b_vectors directory.")
                    else:
                        # Generate a random x vector
                        print(f"{b_vector_file} not found. Generating solution vector...")
                        x_vector = np.random.rand(matrix.shape[1])

                        # Multiply matrix by x to get the solution vector b
                        b_vector = matrix.dot(x_vector)

                        # Save the result in Market Matrix format in the b_vectors subdirectory
                        mmwrite(b_vector_file, csr_matrix(b_vector.reshape(-1, 1)))
                        print(f"Saved b vector: {b_vector_file}")

                except Exception as e:
                    print(f"Failed to create ILU for {filename_root}: {e}")
                    print("Skipping move of matrix and b vector files due to ILU failure.")
                    continue  # Skip moving files if ILU fails

if __name__ == "__main__":
    # Set the directory containing the data
    data_directory = "/Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/small_ILU/new_matrices"
    
    # Process matrices, create ILU preconditioners, and move files
    process_matrices_and_create_ilu(data_directory)
# Out:
# Processing matrix: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/small_ILU/new_matrices/bcspwr01/bcspwr01.mtx
# Attempting to create ILU preconditioner for /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/small_ILU/new_matrices/bcspwr01/bcspwr01.mtx...
# Saved ILU preconditioner to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/small_ILU/new_matrices/ilu_matrices/bcspwr01_ilu.mtx
# Moved matrix file to /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/small_ILU/new_matrices/matrices/bcspwr01.mtx
# /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/small_ILU/new_matrices/b_vectors/bcspwr01_b.mtx not found. Generating solution vector...
# Saved b vector: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/small_ILU/new_matrices/b_vectors/bcspwr01_b.mtx

# %%
import os
import numpy as np
from scipy.io import mmread, mmwrite
from scipy.sparse import csr_matrix

def create_b_vector(matrix_file):
    # Load the matrix from the .mtx file
    matrix = mmread(matrix_file)
    
    # Ensure the matrix is in sparse format
    if not isinstance(matrix, csr_matrix):
        matrix = csr_matrix(matrix)

    # Create a random x vector
    x_vector = np.random.rand(matrix.shape[1])

    # Multiply matrix by x to get the b vector
    b_vector = matrix.dot(x_vector)

    # Create the output filename for the b vector
    filename_root = os.path.splitext(matrix_file)[0]
    b_vector_file = f"{filename_root}_b.mtx"

    # Save the b vector as an .mtx file
    mmwrite(b_vector_file, csr_matrix(b_vector.reshape(-1, 1)))
    print(f"Saved b vector to: {b_vector_file}")

if __name__ == "__main__":
    # Example usage
    matrix_file = "/Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/small_ILU/matrices/Trefethen_20.mtx"
    create_b_vector(matrix_file)
# Out:
# Saved b vector to: /Users/tonylizza/Documents/Machine_Learning/Thesis_Coding/gflownet-spai/data/small_ILU/matrices/Trefethen_20_b.mtx
